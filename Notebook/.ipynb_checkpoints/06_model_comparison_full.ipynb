# %% [markdown]
# # Model Performance Comparison
# This notebook compares Deep Q-Learning (DQL) performance against Autoencoder, Isolation Forest, Local Outlier Factor, and MLP Classifier.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Create comparison table without Deep Q-Learning
data = {
    'Model': ['Autoencoder', 'Isolation Forest', 'Local Outlier Factor', 'MLP Classifier'],
    'Type': ['Unsupervised NN', 'Unsupervised Classical', 'Unsupervised Classical', 'Supervised NN'],
    'Macro Avg F1-Score': [0.922, 0.93, 0.4302, 0.88],
    'Accuracy': [0.9778, 0.98, 0.85, 0.96]
}

df = pd.DataFrame(data)
df
# Out:
#                   Model                    Type  Macro Avg F1-Score  Accuracy
# 0           Autoencoder         Unsupervised NN              0.9220    0.9778
# 1      Isolation Forest  Unsupervised Classical              0.9300    0.9800
# 2  Local Outlier Factor  Unsupervised Classical              0.4302    0.8500
# 3        MLP Classifier           Supervised NN              0.8800    0.9600

# %%
# Plot DQL performance over episodes
episodes = list(range(1, 23))
f1_scores = [0.3, 0.38, 0.42, 0.5, 0.53,
             0.595, 0.6, 0.60, 0.61, 0.62, 0.63, 0.64, 0.66, 0.70, 0.71, 0.72, 0.76, 0.80, 0.81, 0.89, 0.9, 0.92]  # 23 F1 values
autoencoder_f1 = 0.9797
isolation_forest_f1 = 0.8947

plt.figure(figsize=(10, 6))
plt.plot(episodes, f1_scores, marker='o', label='Autoencoder (0.92)', linewidth=2)
plt.xlabel('Episode wise')
plt.ylabel('Macro F1-Score')
plt.title('Deep Q-Learning (DQL) Macro F1-Score Over Episodes vs Other Models')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
